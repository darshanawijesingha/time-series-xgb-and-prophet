# %%
pip install --upgrade numpy scipy scikit-learn xgboost prophet

# %%
pip install tensorflow-cpu==2.12.0

# %%
import pandas as pd 
import numpy as np

# %%
spar_pickme = pd.read_csv('spk_item_report_finance_purpose-item_csv-3eb52f9c8099-2025-05-28-07-31-44.csv')
spar_pickme.head(5)
# Out:
#                             restaurant service_group_code  ResturantId  \
# 0  Celeste Daily at SPAR (Union Place)       MARKET_PLACE        49823
# 1  Celeste Daily at SPAR (Union Place)       MARKET_PLACE        49823
# 2  Celeste Daily at SPAR (Union Place)       MARKET_PLACE        49823
# 3  Celeste Daily at SPAR (Union Place)       MARKET_PLACE        49823
# 4  Celeste Daily at SPAR (Union Place)       MARKET_PLACE        49823
#
#      orderid created_Date created_Time pickup_time completed_time  \
# 0  161080161    7/16/2024     19:19:21     19:21.0        53:00.0
# 1  161075779    7/16/2024     15:36:01     36:01.0        00:10.0
# 2  161072958    7/16/2024     13:28:49     28:49.0        06:30.0
# 3  161075202    7/16/2024     15:01:11     01:11.0        39:00.0
# 4  161072062    7/16/2024     12:59:57     59:57.0        41:22.0
#
#                                                 item  Item_ID  quantity  \
# 0       Maggi Coconut Milk Powder 125g - Sku 3017498      NaN         1
# 1              Finch Garlic Powder 50g - Sku 3011963      NaN         1
# 2            Dilmah Leaf Tea Prem 200g - Sku 3000362      NaN         1
# 3  Richlife Pas. Milk  Bottle Strawberry 500ml - ...      NaN         1
# 4            Kotmale Fresh Cream 200ml - Sku 4507977      NaN         2
#
#    Item_price  ItemTotal district
# 0       440.0      440.0  Colombo
# 1       690.0      690.0  Colombo
# 2       715.0      715.0  Colombo
# 3       440.0      440.0  Colombo
# 4       580.0     1160.0  Colombo

# %%
spar_uber_11 = pd.read_csv('7ce2ca93-fcb4-4ee0-828e-df312c3ce347-india.csv')
spar_uber_11
# Out:
#                                 Store Name  Store ID Order ID  \
# 0      Celeste Daily at SPAR - Union Place       NaN   #483F4
# 1      Celeste Daily at SPAR - Union Place       NaN   #32B10
# 2      Celeste Daily at SPAR - Union Place       NaN   #88FD3
# 3      Celeste Daily at SPAR - Union Place       NaN   #E7A3A
# 4      Celeste Daily at SPAR - Union Place       NaN   #EAB6D
# ...                                    ...       ...      ...
# 15563                                  NaN       NaN      NaN
# 15564                                  NaN       NaN      NaN
# 15565                                  NaN       NaN      NaN
# 15566                                  NaN       NaN      NaN
# 15567                                  NaN       NaN      NaN
#
#                                 Workflow ID Order Date Order Accept Time  \
# 0      96da27f3-8e4e-4280-9c37-ef7aea9483f4  11/1/2024           7:43 AM
# 1      5d92244e-5f83-44ce-8aa1-9f07e8b32b10  11/1/2024           7:55 AM
# 2      77109149-3237-47a7-9de5-a68f86688fd3  11/1/2024           8:50 AM
# 3      c9c05b87-c795-4b25-9979-0081650e7a3a  11/1/2024           8:53 AM
# 4      1dfbeed1-7ffd-4b08-a79f-d688fbdeab6d  11/1/2024           9:31 AM
# ...                                     ...        ...               ...
# 15563                                   NaN        NaN               NaN
# 15564                                   NaN        NaN               NaN
# 15565                                   NaN        NaN               NaN
# 15566                                   NaN        NaN               NaN
# 15567                                   NaN        NaN               NaN
#
#                              Dining Mode Payment Mode Order Channel  \
# 0      Delivery - Partner Using Uber App      Unknown       Android
# 1      Delivery - Partner Using Uber App      Unknown           iOS
# 2      Delivery - Partner Using Uber App      Unknown           iOS
# 3      Delivery - Partner Using Uber App      Unknown           iOS
# 4      Delivery - Partner Using Uber App      Unknown           iOS
# ...                                  ...          ...           ...
# 15563                                NaN          NaN           NaN
# 15564                                NaN          NaN           NaN
# 15565                                NaN          NaN           NaN
# 15566                                NaN          NaN           NaN
# 15567                                NaN          NaN           NaN
#
#       Order Status  ... Other payments description  \
# 0        Completed  ...                        NaN
# 1        Completed  ...                        NaN
# 2        Completed  ...                        NaN
# 3        Completed  ...                        NaN
# 4        Completed  ...                        NaN
# ...            ...  ...                        ...
# 15563          NaN  ...                        NaN
# 15564          NaN  ...                        NaN
# 15565          NaN  ...                        NaN
# 15566          NaN  ...                        NaN
# 15567          NaN  ...                        NaN
#
#        Other payments (incl. tax)  Total payout   Payout Date  Payout Status  \
# 0                             0.0         331.20    11/4/2024           Paid
# 1                             0.0        1501.50    11/4/2024           Paid
# 2                             0.0         345.00    11/4/2024           Paid
# 3                             0.0        1220.19    11/4/2024           Paid
# 4                             0.0        2336.44    11/4/2024           Paid
# ...                           ...            ...          ...            ...
# 15563                         NaN            NaN          NaN            NaN
# 15564                         NaN            NaN          NaN            NaN
# 15565                         NaN            NaN          NaN            NaN
# 15566                         NaN            NaN          NaN            NaN
# 15567                         NaN            NaN          NaN            NaN
#
#        Invoice link U2R   Invoice link C2R   Invoice link R2E   \
# 0                    NaN                NaN                NaN
# 1                    NaN                NaN                NaN
# 2                    NaN                NaN                NaN
# 3                    NaN                NaN                NaN
# 4                    NaN                NaN                NaN
# ...                  ...                ...                ...
# 15563                NaN                NaN                NaN
# 15564                NaN                NaN                NaN
# 15565                NaN                NaN                NaN
# 15566                NaN                NaN                NaN
# 15567                NaN                NaN                NaN
#
#        Retailer Loyalty ID  Payout reference ID
# 0                      NaN      KOAFYPL4WF3QHA5
# 1                      NaN      KOAFYPL4WF3QHA5
# 2                      NaN      KOAFYPL4WF3QHA5
# 3                      NaN      KOAFYPL4WF3QHA5
# 4                      NaN      KOAFYPL4WF3QHA5
# ...                    ...                  ...
# 15563                  NaN                  NaN
# 15564                  NaN                  NaN
# 15565                  NaN                  NaN
# 15566                  NaN                  NaN
# 15567                  NaN                  NaN
#
# [15568 rows x 46 columns]

# %%
spar_uber_6 = pd.read_csv('2d965370-554f-4348-9661-0db7d7add917-india.csv')
spar_uber_6
# Out:
#                                Store Name  Store ID Order ID  \
# 0     Celeste Daily at SPAR - Union Place       NaN   #F051C
# 1     Celeste Daily at SPAR - Union Place       NaN   #3AF21
# 2     Celeste Daily at SPAR - Union Place       NaN   #251C3
# 3     Celeste Daily at SPAR - Union Place       NaN   #00C80
# 4     Celeste Daily at SPAR - Union Place       NaN   #DF05C
# ...                                   ...       ...      ...
# 4943  Celeste Daily at SPAR - Union Place       NaN   #C618D
# 4944  Celeste Daily at SPAR - Union Place       NaN   #D2ED1
# 4945  Celeste Daily at SPAR - Union Place       NaN   #2CB0D
# 4946  Celeste Daily at SPAR - Union Place       NaN   #C0478
# 4947  Celeste Daily at SPAR - Union Place       NaN   #07EF9
#
#                                Workflow ID  Order Date Order Accept Time  \
# 0     6eef99c5-3e60-4750-8d77-e7a4c9df051c   7/16/2024          10:00 AM
# 1     2d11b765-e4e3-482a-a9a3-57e4a273af21   7/16/2024           9:56 AM
# 2     2aafa5c7-def2-42b8-a434-4a1177b251c3   7/16/2024          10:07 AM
# 3     1b01880f-99c5-4557-a2fe-a98a3d200c80   7/16/2024          11:07 AM
# 4     5ace429d-8012-43fc-8d44-213ffe2df05c   7/16/2024          11:43 AM
# ...                                    ...         ...               ...
# 4943  4f0e112a-4052-49be-ad60-fa78ea6c618d  10/31/2024           8:18 PM
# 4944  be454292-5174-4989-b3bf-830292bd2ed1  10/31/2024           9:36 PM
# 4945  c94fa6d7-f255-4a8b-b197-89d2c5c2cb0d  10/31/2024           8:45 PM
# 4946  fafccc77-9e07-4fa5-8ea4-a04d422c0478  10/31/2024           9:21 PM
# 4947  c11e91b8-81e3-41f9-b772-a49517d07ef9  10/31/2024           9:49 PM
#
#                             Dining Mode Payment Mode  Order Channel  \
# 0     Delivery - Partner Using Uber App      Unknown        Android
# 1     Delivery - Partner Using Uber App      Unknown            iOS
# 2     Delivery - Partner Using Uber App      Unknown            iOS
# 3     Delivery - Partner Using Uber App      Unknown            iOS
# 4     Delivery - Partner Using Uber App      Unknown        Android
# ...                                 ...          ...            ...
# 4943  Delivery - Partner Using Uber App      Unknown  Uber Eats Web
# 4944  Delivery - Partner Using Uber App      Unknown            iOS
# 4945  Delivery - Partner Using Uber App      Unknown        Android
# 4946  Delivery - Partner Using Uber App      Unknown  Uber Eats Web
# 4947  Delivery - Partner Using Uber App      Unknown  Uber Eats Web
#
#      Order Status  ... Other payments description  Other payments (incl. tax)  \
# 0       Completed  ...                        NaN                         0.0
# 1       Completed  ...                        NaN                         0.0
# 2       Completed  ...                        NaN                         0.0
# 3       Completed  ...                        NaN                         0.0
# 4       Completed  ...                        NaN                         0.0
# ...           ...  ...                        ...                         ...
# 4943    Completed  ...                        NaN                         0.0
# 4944    Completed  ...                        NaN                         0.0
# 4945    Completed  ...                        NaN                         0.0
# 4946    Completed  ...                        NaN                         0.0
# 4947    Completed  ...                        NaN                         0.0
#
#       Total payout   Payout Date  Payout Status  Invoice link U2R   \
# 0           1045.59    7/22/2024           Paid                NaN
# 1           1638.00    7/22/2024           Paid                NaN
# 2           1392.30    7/22/2024           Paid                NaN
# 3           3708.06    7/22/2024           Paid                NaN
# 4           1319.50    7/22/2024           Paid                NaN
# ...             ...          ...            ...                ...
# 4943         266.80    11/4/2024           Paid                NaN
# 4944        1442.35    11/4/2024           Paid                NaN
# 4945        1883.70    11/4/2024           Paid                NaN
# 4946         717.60    11/4/2024           Paid                NaN
# 4947         322.00    11/4/2024           Paid                NaN
#
#       Invoice link C2R   Invoice link R2E   Retailer Loyalty ID  \
# 0                   NaN                NaN                  NaN
# 1                   NaN                NaN                  NaN
# 2                   NaN                NaN                  NaN
# 3                   NaN                NaN                  NaN
# 4                   NaN                NaN                  NaN
# ...                 ...                ...                  ...
# 4943                NaN                NaN                  NaN
# 4944                NaN                NaN                  NaN
# 4945                NaN                NaN                  NaN
# 4946                NaN                NaN                  NaN
# 4947                NaN                NaN                  NaN
#
#       Payout reference ID
# 0         ROP994SF9BXUEUL
# 1         ROP994SF9BXUEUL
# 2         ROP994SF9BXUEUL
# 3         ROP994SF9BXUEUL
# 4         ROP994SF9BXUEUL
# ...                   ...
# 4943      KOAFYPL4WF3QHA5
# 4944      KOAFYPL4WF3QHA5
# 4945      KOAFYPL4WF3QHA5
# 4946      KOAFYPL4WF3QHA5
# 4947      KOAFYPL4WF3QHA5
#
# [4948 rows x 46 columns]

# %%
spar_uber = pd.concat([spar_uber_11, spar_uber_6], ignore_index=True)
spar_uber
# Out:
#                                 Store Name  Store ID Order ID  \
# 0      Celeste Daily at SPAR - Union Place       NaN   #483F4
# 1      Celeste Daily at SPAR - Union Place       NaN   #32B10
# 2      Celeste Daily at SPAR - Union Place       NaN   #88FD3
# 3      Celeste Daily at SPAR - Union Place       NaN   #E7A3A
# 4      Celeste Daily at SPAR - Union Place       NaN   #EAB6D
# ...                                    ...       ...      ...
# 20511  Celeste Daily at SPAR - Union Place       NaN   #C618D
# 20512  Celeste Daily at SPAR - Union Place       NaN   #D2ED1
# 20513  Celeste Daily at SPAR - Union Place       NaN   #2CB0D
# 20514  Celeste Daily at SPAR - Union Place       NaN   #C0478
# 20515  Celeste Daily at SPAR - Union Place       NaN   #07EF9
#
#                                 Workflow ID  Order Date Order Accept Time  \
# 0      96da27f3-8e4e-4280-9c37-ef7aea9483f4   11/1/2024           7:43 AM
# 1      5d92244e-5f83-44ce-8aa1-9f07e8b32b10   11/1/2024           7:55 AM
# 2      77109149-3237-47a7-9de5-a68f86688fd3   11/1/2024           8:50 AM
# 3      c9c05b87-c795-4b25-9979-0081650e7a3a   11/1/2024           8:53 AM
# 4      1dfbeed1-7ffd-4b08-a79f-d688fbdeab6d   11/1/2024           9:31 AM
# ...                                     ...         ...               ...
# 20511  4f0e112a-4052-49be-ad60-fa78ea6c618d  10/31/2024           8:18 PM
# 20512  be454292-5174-4989-b3bf-830292bd2ed1  10/31/2024           9:36 PM
# 20513  c94fa6d7-f255-4a8b-b197-89d2c5c2cb0d  10/31/2024           8:45 PM
# 20514  fafccc77-9e07-4fa5-8ea4-a04d422c0478  10/31/2024           9:21 PM
# 20515  c11e91b8-81e3-41f9-b772-a49517d07ef9  10/31/2024           9:49 PM
#
#                              Dining Mode Payment Mode  Order Channel  \
# 0      Delivery - Partner Using Uber App      Unknown        Android
# 1      Delivery - Partner Using Uber App      Unknown            iOS
# 2      Delivery - Partner Using Uber App      Unknown            iOS
# 3      Delivery - Partner Using Uber App      Unknown            iOS
# 4      Delivery - Partner Using Uber App      Unknown            iOS
# ...                                  ...          ...            ...
# 20511  Delivery - Partner Using Uber App      Unknown  Uber Eats Web
# 20512  Delivery - Partner Using Uber App      Unknown            iOS
# 20513  Delivery - Partner Using Uber App      Unknown        Android
# 20514  Delivery - Partner Using Uber App      Unknown  Uber Eats Web
# 20515  Delivery - Partner Using Uber App      Unknown  Uber Eats Web
#
#       Order Status  ... Other payments description  \
# 0        Completed  ...                        NaN
# 1        Completed  ...                        NaN
# 2        Completed  ...                        NaN
# 3        Completed  ...                        NaN
# 4        Completed  ...                        NaN
# ...            ...  ...                        ...
# 20511    Completed  ...                        NaN
# 20512    Completed  ...                        NaN
# 20513    Completed  ...                        NaN
# 20514    Completed  ...                        NaN
# 20515    Completed  ...                        NaN
#
#        Other payments (incl. tax)  Total payout   Payout Date  Payout Status  \
# 0                             0.0         331.20    11/4/2024           Paid
# 1                             0.0        1501.50    11/4/2024           Paid
# 2                             0.0         345.00    11/4/2024           Paid
# 3                             0.0        1220.19    11/4/2024           Paid
# 4                             0.0        2336.44    11/4/2024           Paid
# ...                           ...            ...          ...            ...
# 20511                         0.0         266.80    11/4/2024           Paid
# 20512                         0.0        1442.35    11/4/2024           Paid
# 20513                         0.0        1883.70    11/4/2024           Paid
# 20514                         0.0         717.60    11/4/2024           Paid
# 20515                         0.0         322.00    11/4/2024           Paid
#
#        Invoice link U2R   Invoice link C2R   Invoice link R2E   \
# 0                    NaN                NaN                NaN
# 1                    NaN                NaN                NaN
# 2                    NaN                NaN                NaN
# 3                    NaN                NaN                NaN
# 4                    NaN                NaN                NaN
# ...                  ...                ...                ...
# 20511                NaN                NaN                NaN
# 20512                NaN                NaN                NaN
# 20513                NaN                NaN                NaN
# 20514                NaN                NaN                NaN
# 20515                NaN                NaN                NaN
#
#        Retailer Loyalty ID  Payout reference ID
# 0                      NaN      KOAFYPL4WF3QHA5
# 1                      NaN      KOAFYPL4WF3QHA5
# 2                      NaN      KOAFYPL4WF3QHA5
# 3                      NaN      KOAFYPL4WF3QHA5
# 4                      NaN      KOAFYPL4WF3QHA5
# ...                    ...                  ...
# 20511                  NaN      KOAFYPL4WF3QHA5
# 20512                  NaN      KOAFYPL4WF3QHA5
# 20513                  NaN      KOAFYPL4WF3QHA5
# 20514                  NaN      KOAFYPL4WF3QHA5
# 20515                  NaN      KOAFYPL4WF3QHA5
#
# [20516 rows x 46 columns]

# %%
up_spar_pickme = spar_pickme[spar_pickme['restaurant'] == "kuruduwaththa"]
up_spar_pickme
# Out:
#                                 restaurant service_group_code  ResturantId  \
# 0      Celeste Daily at SPAR (Union Place)       MARKET_PLACE        49823
# 1      Celeste Daily at SPAR (Union Place)       MARKET_PLACE        49823
# 2      Celeste Daily at SPAR (Union Place)       MARKET_PLACE        49823
# 3      Celeste Daily at SPAR (Union Place)       MARKET_PLACE        49823
# 4      Celeste Daily at SPAR (Union Place)       MARKET_PLACE        49823
# ...                                    ...                ...          ...
# 82104  Celeste Daily at SPAR (Union Place)       MARKET_PLACE        49823
# 82120  Celeste Daily at SPAR (Union Place)       MARKET_PLACE        49823
# 82124  Celeste Daily at SPAR (Union Place)       MARKET_PLACE        49823
# 82128  Celeste Daily at SPAR (Union Place)       MARKET_PLACE        49823
# 82131  Celeste Daily at SPAR (Union Place)       MARKET_PLACE        49823
#
#          orderid created_Date created_Time pickup_time completed_time  \
# 0      161080161    7/16/2024     19:19:21     19:21.0        53:00.0
# 1      161075779    7/16/2024     15:36:01     36:01.0        00:10.0
# 2      161072958    7/16/2024     13:28:49     28:49.0        06:30.0
# 3      161075202    7/16/2024     15:01:11     01:11.0        39:00.0
# 4      161072062    7/16/2024     12:59:57     59:57.0        41:22.0
# ...          ...          ...          ...         ...            ...
# 82104  168156968    5/27/2025     11:27:07     27:07.0        56:42.0
# 82120  168164112    5/27/2025     14:57:58     57:58.0        25:37.0
# 82124  168174013    5/27/2025     20:40:46     40:46.0        04:08.0
# 82128  168153480    5/27/2025      7:00:56     00:56.0        31:36.0
# 82131  168163254    5/27/2025     14:22:36     22:36.0        05:09.0
#
#                                                     item  Item_ID  quantity  \
# 0           Maggi Coconut Milk Powder 125g - Sku 3017498      NaN         1
# 1                  Finch Garlic Powder 50g - Sku 3011963      NaN         1
# 2                Dilmah Leaf Tea Prem 200g - Sku 3000362      NaN         1
# 3      Richlife Pas. Milk  Bottle Strawberry 500ml - ...      NaN         1
# 4                Kotmale Fresh Cream 200ml - Sku 4507977      NaN         2
# ...                                                  ...      ...       ...
# 82104               Carrot 250-300G - SPAR - SKU 4503950      NaN         2
# 82120                Sams Chicken Ham 150G - SKU 4503246      NaN         2
# 82124    Anchor Newdale Yoghurt Value Pack - Sku 4503436      NaN         1
# 82128  Sprats With Head (Dried Fish) 100G - Prime Fre...      NaN         2
# 82131       Red Grapes 100G - 110G  - Spar - SKU 4504203      NaN         1
#
#        Item_price  ItemTotal district
# 0           440.0      440.0  Colombo
# 1           690.0      690.0  Colombo
# 2           715.0      715.0  Colombo
# 3           440.0      440.0  Colombo
# 4           580.0     1160.0  Colombo
# ...           ...        ...      ...
# 82104       383.2      766.4  Colombo
# 82120       610.0     1220.0  Colombo
# 82124       490.0      490.0  Colombo
# 82128       320.0      640.0  Colombo
# 82131       279.2      279.2  Colombo
#
# [22981 rows x 14 columns]

# %%
spar_uber['Order Date']= pd.to_datetime(spar_uber['Order Date'])
spar_uber
# Out:
#                                 Store Name  Store ID Order ID  \
# 0      Celeste Daily at SPAR - Union Place       NaN   #483F4
# 1      Celeste Daily at SPAR - Union Place       NaN   #32B10
# 2      Celeste Daily at SPAR - Union Place       NaN   #88FD3
# 3      Celeste Daily at SPAR - Union Place       NaN   #E7A3A
# 4      Celeste Daily at SPAR - Union Place       NaN   #EAB6D
# ...                                    ...       ...      ...
# 20511  Celeste Daily at SPAR - Union Place       NaN   #C618D
# 20512  Celeste Daily at SPAR - Union Place       NaN   #D2ED1
# 20513  Celeste Daily at SPAR - Union Place       NaN   #2CB0D
# 20514  Celeste Daily at SPAR - Union Place       NaN   #C0478
# 20515  Celeste Daily at SPAR - Union Place       NaN   #07EF9
#
#                                 Workflow ID Order Date Order Accept Time  \
# 0      96da27f3-8e4e-4280-9c37-ef7aea9483f4 2024-11-01           7:43 AM
# 1      5d92244e-5f83-44ce-8aa1-9f07e8b32b10 2024-11-01           7:55 AM
# 2      77109149-3237-47a7-9de5-a68f86688fd3 2024-11-01           8:50 AM
# 3      c9c05b87-c795-4b25-9979-0081650e7a3a 2024-11-01           8:53 AM
# 4      1dfbeed1-7ffd-4b08-a79f-d688fbdeab6d 2024-11-01           9:31 AM
# ...                                     ...        ...               ...
# 20511  4f0e112a-4052-49be-ad60-fa78ea6c618d 2024-10-31           8:18 PM
# 20512  be454292-5174-4989-b3bf-830292bd2ed1 2024-10-31           9:36 PM
# 20513  c94fa6d7-f255-4a8b-b197-89d2c5c2cb0d 2024-10-31           8:45 PM
# 20514  fafccc77-9e07-4fa5-8ea4-a04d422c0478 2024-10-31           9:21 PM
# 20515  c11e91b8-81e3-41f9-b772-a49517d07ef9 2024-10-31           9:49 PM
#
#                              Dining Mode Payment Mode  Order Channel  \
# 0      Delivery - Partner Using Uber App      Unknown        Android
# 1      Delivery - Partner Using Uber App      Unknown            iOS
# 2      Delivery - Partner Using Uber App      Unknown            iOS
# 3      Delivery - Partner Using Uber App      Unknown            iOS
# 4      Delivery - Partner Using Uber App      Unknown            iOS
# ...                                  ...          ...            ...
# 20511  Delivery - Partner Using Uber App      Unknown  Uber Eats Web
# 20512  Delivery - Partner Using Uber App      Unknown            iOS
# 20513  Delivery - Partner Using Uber App      Unknown        Android
# 20514  Delivery - Partner Using Uber App      Unknown  Uber Eats Web
# 20515  Delivery - Partner Using Uber App      Unknown  Uber Eats Web
#
#       Order Status  ... Other payments description  \
# 0        Completed  ...                        NaN
# 1        Completed  ...                        NaN
# 2        Completed  ...                        NaN
# 3        Completed  ...                        NaN
# 4        Completed  ...                        NaN
# ...            ...  ...                        ...
# 20511    Completed  ...                        NaN
# 20512    Completed  ...                        NaN
# 20513    Completed  ...                        NaN
# 20514    Completed  ...                        NaN
# 20515    Completed  ...                        NaN
#
#        Other payments (incl. tax)  Total payout   Payout Date  Payout Status  \
# 0                             0.0         331.20    11/4/2024           Paid
# 1                             0.0        1501.50    11/4/2024           Paid
# 2                             0.0         345.00    11/4/2024           Paid
# 3                             0.0        1220.19    11/4/2024           Paid
# 4                             0.0        2336.44    11/4/2024           Paid
# ...                           ...            ...          ...            ...
# 20511                         0.0         266.80    11/4/2024           Paid
# 20512                         0.0        1442.35    11/4/2024           Paid
# 20513                         0.0        1883.70    11/4/2024           Paid
# 20514                         0.0         717.60    11/4/2024           Paid
# 20515                         0.0         322.00    11/4/2024           Paid
#
#        Invoice link U2R   Invoice link C2R   Invoice link R2E   \
# 0                    NaN                NaN                NaN
# 1                    NaN                NaN                NaN
# 2                    NaN                NaN                NaN
# 3                    NaN                NaN                NaN
# 4                    NaN                NaN                NaN
# ...                  ...                ...                ...
# 20511                NaN                NaN                NaN
# 20512                NaN                NaN                NaN
# 20513                NaN                NaN                NaN
# 20514                NaN                NaN                NaN
# 20515                NaN                NaN                NaN
#
#        Retailer Loyalty ID  Payout reference ID
# 0                      NaN      KOAFYPL4WF3QHA5
# 1                      NaN      KOAFYPL4WF3QHA5
# 2                      NaN      KOAFYPL4WF3QHA5
# 3                      NaN      KOAFYPL4WF3QHA5
# 4                      NaN      KOAFYPL4WF3QHA5
# ...                    ...                  ...
# 20511                  NaN      KOAFYPL4WF3QHA5
# 20512                  NaN      KOAFYPL4WF3QHA5
# 20513                  NaN      KOAFYPL4WF3QHA5
# 20514                  NaN      KOAFYPL4WF3QHA5
# 20515                  NaN      KOAFYPL4WF3QHA5
#
# [20516 rows x 46 columns]

# %%
up_spar_pickme.columns
# Out:
# Index(['restaurant', 'service_group_code', 'ResturantId', 'orderid',
#        'created_Date', 'created_Time', 'pickup_time', 'completed_time', 'item',
#        'Item_ID', 'quantity', 'Item_price', 'ItemTotal', 'district'],
#       dtype='object')

# %%
# Ensure created_Date is in datetime format
up_spar_pickme['created_Date'] = pd.to_datetime(up_spar_pickme['created_Date'])
up_spar_pickme
# Out:
#                                 restaurant service_group_code  ResturantId  \
# 0      Celeste Daily at SPAR (Union Place)       MARKET_PLACE        49823
# 1      Celeste Daily at SPAR (Union Place)       MARKET_PLACE        49823
# 2      Celeste Daily at SPAR (Union Place)       MARKET_PLACE        49823
# 3      Celeste Daily at SPAR (Union Place)       MARKET_PLACE        49823
# 4      Celeste Daily at SPAR (Union Place)       MARKET_PLACE        49823
# ...                                    ...                ...          ...
# 82104  Celeste Daily at SPAR (Union Place)       MARKET_PLACE        49823
# 82120  Celeste Daily at SPAR (Union Place)       MARKET_PLACE        49823
# 82124  Celeste Daily at SPAR (Union Place)       MARKET_PLACE        49823
# 82128  Celeste Daily at SPAR (Union Place)       MARKET_PLACE        49823
# 82131  Celeste Daily at SPAR (Union Place)       MARKET_PLACE        49823
#
#          orderid created_Date created_Time pickup_time completed_time  \
# 0      161080161   2024-07-16     19:19:21     19:21.0        53:00.0
# 1      161075779   2024-07-16     15:36:01     36:01.0        00:10.0
# 2      161072958   2024-07-16     13:28:49     28:49.0        06:30.0
# 3      161075202   2024-07-16     15:01:11     01:11.0        39:00.0
# 4      161072062   2024-07-16     12:59:57     59:57.0        41:22.0
# ...          ...          ...          ...         ...            ...
# 82104  168156968   2025-05-27     11:27:07     27:07.0        56:42.0
# 82120  168164112   2025-05-27     14:57:58     57:58.0        25:37.0
# 82124  168174013   2025-05-27     20:40:46     40:46.0        04:08.0
# 82128  168153480   2025-05-27      7:00:56     00:56.0        31:36.0
# 82131  168163254   2025-05-27     14:22:36     22:36.0        05:09.0
#
#                                                     item  Item_ID  quantity  \
# 0           Maggi Coconut Milk Powder 125g - Sku 3017498      NaN         1
# 1                  Finch Garlic Powder 50g - Sku 3011963      NaN         1
# 2                Dilmah Leaf Tea Prem 200g - Sku 3000362      NaN         1
# 3      Richlife Pas. Milk  Bottle Strawberry 500ml - ...      NaN         1
# 4                Kotmale Fresh Cream 200ml - Sku 4507977      NaN         2
# ...                                                  ...      ...       ...
# 82104               Carrot 250-300G - SPAR - SKU 4503950      NaN         2
# 82120                Sams Chicken Ham 150G - SKU 4503246      NaN         2
# 82124    Anchor Newdale Yoghurt Value Pack - Sku 4503436      NaN         1
# 82128  Sprats With Head (Dried Fish) 100G - Prime Fre...      NaN         2
# 82131       Red Grapes 100G - 110G  - Spar - SKU 4504203      NaN         1
#
#        Item_price  ItemTotal district
# 0           440.0      440.0  Colombo
# 1           690.0      690.0  Colombo
# 2           715.0      715.0  Colombo
# 3           440.0      440.0  Colombo
# 4           580.0     1160.0  Colombo
# ...           ...        ...      ...
# 82104       383.2      766.4  Colombo
# 82120       610.0     1220.0  Colombo
# 82124       490.0      490.0  Colombo
# 82128       320.0      640.0  Colombo
# 82131       279.2      279.2  Colombo
#
# [22981 rows x 14 columns]

# %%
spar_uber.columns
# Out:
# Index(['Store Name', 'Store ID', 'Order ID', 'Workflow ID', 'Order Date',
#        'Order Accept Time', 'Dining Mode', 'Payment Mode', 'Order Channel',
#        'Order Status', 'Customer Uber-Membership Status', 'Sales (excl. tax)',
#        'Tax on sales', 'Refunds (excl tax)', 'Tax on Refunds',
#        'Price adjustments (excl. tax)', 'Tax on price adjustments',
#        'Promotions on items (excl tax)', 'Tax on Promotion on items',
#        'Promotions on items (incl tax)', 'Delivery Charge (excl tax)',
#        'Tax on Delivery Fee', 'Promotions on delivery charge (excl tax)',
#        'Tax on Promotions on delivery charge',
#        'Promotions on delivery charge (incl tax)', 'Bag Fee',
#        'Delivery Fee (excl tax)', 'Tax on Delivery Fee.1',
#        'Delivery Fee (incl tax)', 'Service Fee', 'Tax on Service Fee',
#        'Service Fee Discount', 'Net Service fee', 'Discount Adjustments',
#        'Profit on Delivery', 'Tax Adjustment', 'Other payments description',
#        'Other payments (incl. tax)', 'Total payout ', 'Payout Date',
#        'Payout Status', 'Invoice link U2R ', 'Invoice link C2R ',
#        'Invoice link R2E ', 'Retailer Loyalty ID', 'Payout reference ID'],
#       dtype='object')

# %%
spar_uber = spar_uber.drop(
    ['Store Name', 'Store ID', 'Workflow ID', 
       'Order Accept Time', 'Dining Mode', 'Payment Mode', 'Order Channel',
       'Order Status', 'Customer Uber-Membership Status', 
       'Tax on sales', 'Refunds (excl tax)', 'Tax on Refunds',
       'Price adjustments (excl. tax)', 'Tax on price adjustments',
       'Promotions on items (excl tax)', 'Tax on Promotion on items',
       'Promotions on items (incl tax)', 'Delivery Charge (excl tax)',
       'Tax on Delivery Fee', 'Promotions on delivery charge (excl tax)',
       'Tax on Promotions on delivery charge',
       'Promotions on delivery charge (incl tax)', 'Bag Fee',
       'Delivery Fee (excl tax)', 'Tax on Delivery Fee.1',
       'Delivery Fee (incl tax)', 'Service Fee', 'Tax on Service Fee',
       'Service Fee Discount', 'Net Service fee', 'Discount Adjustments',
       'Profit on Delivery', 'Tax Adjustment', 'Other payments description',
       'Other payments (incl. tax)', 'Total payout ', 'Payout Date',
       'Payout Status', 'Invoice link U2R ', 'Invoice link C2R ',
       'Invoice link R2E ', 'Retailer Loyalty ID', 'Payout reference ID'],
    axis=1
)

# %%
spar_uber
# Out:
#       Order ID Order Date  Sales (excl. tax)
# 0       #483F4 2024-11-01              360.0
# 1       #32B10 2024-11-01             1650.0
# 2       #88FD3 2024-11-01              375.0
# 3       #E7A3A 2024-11-01             1300.0
# 4       #EAB6D 2024-11-01             2320.0
# ...        ...        ...                ...
# 20511   #C618D 2024-10-31              290.0
# 20512   #D2ED1 2024-10-31             1690.0
# 20513   #2CB0D 2024-10-31             1870.0
# 20514   #C0478 2024-10-31              780.0
# 20515   #07EF9 2024-10-31              370.0
#
# [20516 rows x 3 columns]

# %%
up_spar_pickme = up_spar_pickme.drop(
    ['service_group_code', 'ResturantId', 'created_Time', 'pickup_time', 'completed_time', 'item', 'Item_ID', 'district','quantity'],
    axis=1
)

# %%
spar_uber_daily = spar_uber.groupby('Order Date').agg({
    'Sales (excl. tax)': 'sum',
    'Order ID': 'count'
}).rename(columns={
    'Sales (excl. tax)': 'ItemTotal',
    'Order ID': 'order_count'
}).reset_index().rename(columns={
    'Order Date': 'created_Date'
}).set_index('created_Date')

print(spar_uber_daily)
# Out:
#               ItemTotal  order_count
# created_Date
# 2024-07-16      40542.0           24
# 2024-07-17      55910.0           33
# 2024-07-18      38115.0           20
# 2024-07-19      23805.0           14
# 2024-07-20      29988.0           15
# ...                 ...          ...
# 2025-05-23      73488.0           42
# 2025-05-24      99386.0           47
# 2025-05-25     126474.0           52
# 2025-05-26      83450.0           41
# 2025-05-27      92708.0           46
#
# [316 rows x 2 columns]

# %%
up_spar_pickme_daily= up_spar_pickme.groupby('created_Date').agg({
    ##'quantity': 'sum',
    ##'Item_price': 'sum',
    'ItemTotal': 'sum',
    'orderid': 'count'
}).rename(columns={'orderid': 'order_count'})

print(up_spar_pickme_daily)
# Out:
#               ItemTotal  order_count
# created_Date
# 2024-07-16      8780.00           13
# 2024-07-17     16309.00           29
# 2024-07-18     15715.00           27
# 2024-07-19     11679.00            8
# 2024-07-20     10535.00           12
# ...                 ...          ...
# 2025-05-23     60993.55          104
# 2025-05-24     63987.75           92
# 2025-05-25     85165.90          135
# 2025-05-26     60353.90          108
# 2025-05-27     47050.00           80
#
# [316 rows x 2 columns]

# %%
# Step 2: Merge on index with sum for overlapping dates
combined_daily = up_spar_pickme_daily.add(spar_uber_daily, fill_value=0)

# Step 3 (optional): Round numbers or convert counts to int if needed
combined_daily['order_count'] = combined_daily['order_count'].astype(int)

print(combined_daily)
# Out:
#               ItemTotal  order_count
# created_Date
# 2024-07-16     49322.00           37
# 2024-07-17     72219.00           62
# 2024-07-18     53830.00           47
# 2024-07-19     35484.00           22
# 2024-07-20     40523.00           27
# ...                 ...          ...
# 2025-05-23    134481.55          146
# 2025-05-24    163373.75          139
# 2025-05-25    211639.90          187
# 2025-05-26    143803.90          149
# 2025-05-27    139758.00          126
#
# [316 rows x 2 columns]

# %%
combined_daily.columns
# Out:
# Index(['ItemTotal', 'order_count'], dtype='object')

# %%
combined_daily = combined_daily.sort_index()
combined_daily
# Out:
#               ItemTotal  order_count
# created_Date
# 2024-07-16     49322.00           37
# 2024-07-17     72219.00           62
# 2024-07-18     53830.00           47
# 2024-07-19     35484.00           22
# 2024-07-20     40523.00           27
# ...                 ...          ...
# 2025-05-23    134481.55          146
# 2025-05-24    163373.75          139
# 2025-05-25    211639.90          187
# 2025-05-26    143803.90          149
# 2025-05-27    139758.00          126
#
# [316 rows x 2 columns]

# %%
import pandas as pd
import numpy as np
from datetime import timedelta
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error
from prophet import Prophet
import matplotlib.pyplot as plt
import warnings

warnings.filterwarnings("ignore")

# ---- Feature Engineering ----
def create_features(combined_daily, target_col):
    combined_daily = combined_daily.copy()
    combined_daily['dayofweek'] = combined_daily.index.dayofweek
    combined_daily['month'] = combined_daily.index.month
    combined_daily['lag_1'] = combined_daily[target_col].shift(1)
    combined_daily['rolling_3'] = combined_daily[target_col].rolling(3).mean()
    return combined_daily.dropna()

# ---- XGBoost Forecasting ----
def forecast_xgboost(combined_daily, target_col, test_days=30):
    df_feat = create_features(combined_daily, target_col)
    features = ['dayofweek', 'month', 'lag_1', 'rolling_3']

    train = df_feat.iloc[:-test_days]
    test = df_feat.iloc[-test_days:]
    X_train, y_train = train[features], train[target_col]
    X_test, y_test = test[features], test[target_col]

    model = XGBRegressor(n_estimators=100, random_state=42)
    model.fit(X_train, y_train)

    # Predict test set
    test_pred = model.predict(X_test)
    test_rmse = np.sqrt(mean_squared_error(y_test, test_pred))

    # Forecast next 30 days
    future_preds = []
    temp_df = combined_daily.copy()

    for i in range(1, 31):
        date = temp_df.index[-1] + timedelta(days=1)
        row = {
            'dayofweek': date.dayofweek,
            'month': date.month,
            'lag_1': temp_df[target_col].iloc[-1],
            'rolling_3': temp_df[target_col].rolling(3).mean().iloc[-1]
        }
        x_pred = pd.DataFrame([row])
        pred = model.predict(x_pred)[0]
        future_preds.append(pred)
        temp_df.loc[date] = [pred if c == target_col else np.nan for c in temp_df.columns]

    future_index = [temp_df.index[-30 + i] for i in range(30)]
    return pd.Series(future_preds, index=future_index), test_rmse

# ---- Prophet Forecasting ----
def forecast_prophet(combined_daily, target_col, test_days=30):
    prophet_df = combined_daily[[target_col]].reset_index()
    prophet_df.columns = ['ds', 'y']
    train = prophet_df.iloc[:-test_days]
    test = prophet_df.iloc[-test_days:]

    model = Prophet()
    model.fit(train)
    future = model.make_future_dataframe(periods=test_days + 30)
    forecast = model.predict(future)
    forecast = forecast[['ds', 'yhat']].set_index('ds')

    test_forecast = forecast.iloc[-(test_days + 30):-30]
    test_rmse = np.sqrt(mean_squared_error(test.set_index('ds')['y'], test_forecast['yhat']))
    future_forecast = forecast.iloc[-30:]
    return future_forecast['yhat'], test_rmse

# ---- Example Dataset ----
# Ensure you have a DataFrame named `combined_daily` with a datetime index and columns 'ItemTotal' and 'order_count'.
# Example:
# combined_daily = pd.read_csv("your_data.csv", parse_dates=['date'], index_col='date')

# ---- Main Forecast Loop ----
forecast_results = {}
evaluation_metrics = {}

for col in ['ItemTotal', 'order_count']:
    print(f"\nForecasting {col}...")

    xgb_forecast, xgb_rmse = forecast_xgboost(combined_daily[[col]].copy(), col)
    prophet_forecast, prophet_rmse = forecast_prophet(combined_daily[[col]].copy(), col)

    forecast_results[col] = {
        'xgb': xgb_forecast,
        'prophet': prophet_forecast
    }
    evaluation_metrics[col] = {
        'xgb_test_rmse': xgb_rmse,
        'prophet_test_rmse': prophet_rmse
    }

# ---- Combine Results ----
forecast_df = pd.DataFrame({
    f"{col}_xgb": forecast_results[col]['xgb'] for col in forecast_results
}).join(pd.DataFrame({
    f"{col}_prophet": forecast_results[col]['prophet'] for col in forecast_results
}))

print("\n🔍 Forecast Accuracy (RMSE on Test Set):")
for col, scores in evaluation_metrics.items():
    print(f"{col}:")
    for model, score in scores.items():
        print(f"  {model}: {score:.2f}")

# ---- Plot ----
forecast_df.plot(subplots=True, figsize=(14, 10), title="📈 Forecasts for Next 30 Days")
plt.tight_layout()
plt.show()
# Out:
# Forecasting ItemTotal...
# 09:47:23 - cmdstanpy - INFO - Chain [1] start processing
# 09:47:24 - cmdstanpy - INFO - Chain [1] done processing
# Forecasting order_count...
# 09:47:25 - cmdstanpy - INFO - Chain [1] start processing
# 09:47:25 - cmdstanpy - INFO - Chain [1] done processing
# 🔍 Forecast Accuracy (RMSE on Test Set):
# ItemTotal:
#   xgb_test_rmse: 26521.01
#   prophet_test_rmse: 73222.47
# order_count:
#   xgb_test_rmse: 23.69
#   prophet_test_rmse: 58.66

# %%
import pandas as pd
import numpy as np
from datetime import timedelta, datetime
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error
from prophet import Prophet
import matplotlib.pyplot as plt
import warnings

warnings.filterwarnings("ignore")

# ---- Feature Engineering ----
def create_features(combined_daily, target_col):
    combined_daily = combined_daily.copy()
    combined_daily['dayofweek'] = combined_daily.index.dayofweek
    combined_daily['month'] = combined_daily.index.month
    combined_daily['lag_1'] = combined_daily[target_col].shift(1)
    combined_daily['rolling_3'] = combined_daily[target_col].rolling(3).mean()
    return combined_daily.dropna()

# ---- XGBoost Forecasting ----
def forecast_xgboost(combined_daily, target_col, test_days=30):
    df_feat = create_features(combined_daily, target_col)
    features = ['dayofweek', 'month', 'lag_1', 'rolling_3']

    train = df_feat.iloc[:-test_days]
    test = df_feat.iloc[-test_days:]
    X_train, y_train = train[features], train[target_col]
    X_test, y_test = test[features], test[target_col]

    model = XGBRegressor(n_estimators=100, random_state=42)
    model.fit(X_train, y_train)

    # Predict test set
    test_pred = model.predict(X_test)
    test_rmse = np.sqrt(mean_squared_error(y_test, test_pred))

    # Forecast next 30 days
    future_preds = []
    temp_df = combined_daily.copy()

    for i in range(1, 31):
        date = temp_df.index[-1] + timedelta(days=1)
        row = {
            'dayofweek': date.dayofweek,
            'month': date.month,
            'lag_1': temp_df[target_col].iloc[-1],
            'rolling_3': temp_df[target_col].rolling(3).mean().iloc[-1]
        }
        x_pred = pd.DataFrame([row])
        pred = model.predict(x_pred)[0]
        future_preds.append(pred)
        temp_df.loc[date] = [pred if c == target_col else np.nan for c in temp_df.columns]

    future_index = [temp_df.index[-30 + i] for i in range(30)]
    return pd.Series(future_preds, index=future_index), test_rmse, model

# ---- Prophet Forecasting ----
def forecast_prophet(combined_daily, target_col, test_days=30):
    prophet_df = combined_daily[[target_col]].reset_index()
    prophet_df.columns = ['ds', 'y']
    train = prophet_df.iloc[:-test_days]
    test = prophet_df.iloc[-test_days:]

    model = Prophet()
    model.fit(train)
    future = model.make_future_dataframe(periods=test_days + 30)
    forecast = model.predict(future)
    forecast = forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].set_index('ds')

    test_forecast = forecast.iloc[-(test_days + 30):-30]
    test_rmse = np.sqrt(mean_squared_error(test.set_index('ds')['y'], test_forecast['yhat']))
    future_forecast = forecast.iloc[-30:]
    return future_forecast['yhat'], test_rmse, model, future_forecast

# ---- Main Forecast Function ----
def generate_forecasts(combined_daily):
    forecast_results = {}
    evaluation_metrics = {}
    models = {}

    for col in ['ItemTotal', 'order_count']:
        print(f"\nForecasting {col}...")

        # Use Prophet for ItemTotal, XGBoost for order_count
        if col == 'ItemTotal':
            forecast, rmse, model, full_forecast = forecast_prophet(combined_daily[[col]].copy(), col)
            forecast_results[col] = {
                'forecast': forecast,
                'rmse': rmse,
                'model': 'prophet',
                'full_forecast': full_forecast
            }
        else:
            forecast, rmse, model = forecast_xgboost(combined_daily[[col]].copy(), col)
            forecast_results[col] = {
                'forecast': forecast,
                'rmse': rmse,
                'model': 'xgboost'
            }
        evaluation_metrics[col] = {'rmse': rmse}
        models[col] = model

    return forecast_results, evaluation_metrics, models

# ---- Extended Forecast Calculation ----
def calculate_extended_forecast(last_value, rmse, days, growth_rate=0):
    """Calculate extended forecast with optional growth rate"""
    daily_values = [last_value * (1 + growth_rate)**i for i in range(days)]
    total = sum(daily_values)
    # Scale RMSE by sqrt of time period
    total_rmse = rmse * np.sqrt(days/30)
    
    return {
        'total': total,
        'lower_bound': total - total_rmse,
        'upper_bound': total + total_rmse,
        'rmse': total_rmse
    }

# ---- Save Forecasts to Separate CSVs ----
def save_forecasts_separate(forecast_results):
    for col in forecast_results:
        if forecast_results[col]['model'] == 'prophet':
            # For Prophet forecasts
            forecast_df = forecast_results[col]['full_forecast'].copy()
            forecast_df.columns = ['forecast', 'lower_bound', 'upper_bound']
        else:
            # For XGBoost forecasts
            forecast_series = forecast_results[col]['forecast']
            rmse = forecast_results[col]['rmse']
            forecast_df = pd.DataFrame({
                'forecast': forecast_series,
                'lower_bound': forecast_series - rmse,
                'upper_bound': forecast_series + rmse
            })
        
        # Save to separate CSV files
        filename = f"{col}_forecast.csv"
        forecast_df.to_csv(filename)
        print(f"Saved {col} forecast to {filename}")

# ---- Plot Forecasts ----
def plot_forecasts(combined_daily, forecast_results):
    for col in forecast_results:
        plt.figure(figsize=(12, 6))
        
        # Plot historical data
        plt.plot(combined_daily.index, combined_daily[col], label='Historical', color='blue')
        
        # Plot forecast
        forecast = forecast_results[col]['forecast']
        model = forecast_results[col]['model']
        rmse = forecast_results[col]['rmse']
        
        plt.plot(forecast.index, forecast.values, 
                label=f'{model} Forecast', linestyle='--', color='red')
        
        # Add confidence interval
        if model == 'prophet':
            full_forecast = forecast_results[col]['full_forecast']
            plt.fill_between(full_forecast.index,
                            full_forecast['yhat_lower'],
                            full_forecast['yhat_upper'],
                            color='red', alpha=0.2,
                            label='Confidence Interval')
        else:
            plt.fill_between(forecast.index,
                            forecast.values - rmse,
                            forecast.values + rmse,
                            color='red', alpha=0.2,
                            label='± RMSE Margin')
        
        plt.title(f"{col} - {model.capitalize()} Forecast with Confidence Interval")
        plt.xlabel("Date")
        plt.ylabel(col)
        plt.legend()
        plt.grid(True)
        plt.tight_layout()
        plt.show()

# ---- Execute Forecasts ----
# Assuming combined_daily is your input DataFrame with datetime index
# combined_daily = pd.read_csv("your_data.csv", parse_dates=['date'], index_col='date')

forecast_results, evaluation_metrics, models = generate_forecasts(combined_daily)

# 1. Plot 30-day forecasts with margins
plot_forecasts(combined_daily, forecast_results)

# 2. Save forecasts to separate CSV files
save_forecasts_separate(forecast_results)

# 3. Calculate 6-month and 1-year projections
print("\n📈 Extended Forecast Projections:")
for col in forecast_results:
    last_value = forecast_results[col]['forecast'].iloc[-1]
    rmse = forecast_results[col]['rmse']
    model = forecast_results[col]['model']
    
    # Calculate projections (assuming 0% growth rate - adjust as needed)
    six_month = calculate_extended_forecast(last_value, rmse, 180)
    one_year = calculate_extended_forecast(last_value, rmse, 365)
    
    print(f"\n{col} Projections ({model}):")
    print(f"6-Month Total: {six_month['total']:,.2f}")
    print(f"  Range: {six_month['lower_bound']:,.2f} to {six_month['upper_bound']:,.2f}")
    print(f"1-Year Total: {one_year['total']:,.2f}")
    print(f"  Range: {one_year['lower_bound']:,.2f} to {one_year['upper_bound']:,.2f}")
# Out:
# 10:03:57 - cmdstanpy - INFO - Chain [1] start processing
# 10:03:57 - cmdstanpy - INFO - Chain [1] done processing
# Forecasting ItemTotal...
#
# Forecasting order_count...
# Saved ItemTotal forecast to ItemTotal_forecast.csv
# Saved order_count forecast to order_count_forecast.csv
#
# 📈 Extended Forecast Projections:
#
# ItemTotal Projections (prophet):
# 6-Month Total: 36,838,726.35
#   Range: 36,659,368.66 to 37,018,084.04
# 1-Year Total: 74,700,750.65
#   Range: 74,445,345.19 to 74,956,156.11
#
# order_count Projections (xgboost):
# 6-Month Total: 30,042.54
#   Range: 29,984.51 to 30,100.57
# 1-Year Total: 60,919.59
#   Range: 60,836.96 to 61,002.23

# %%
print(pd.read_csv('ItemTotal_forecast.csv').head())
# Out:
#            ds       forecast    lower_bound    upper_bound
# 0  2025-05-28  216995.690700  162223.855377  270514.682455
# 1  2025-05-29  220667.720375  163108.096294  277997.416890
# 2  2025-05-30  204837.472566  146602.722916  260261.559345
# 3  2025-05-31  208482.518705  155260.406734  262902.414095
# 4  2025-06-01  206453.595920  151402.200629  261418.441350

# %%
print(pd.read_csv('order_count_forecast.csv').head())
# Out:
#    Unnamed: 0   forecast  lower_bound  upper_bound
# 0  2025-05-28  152.96560    129.27467    176.65654
# 1  2025-05-29  162.21025    138.51932    185.90118
# 2  2025-05-30  145.07999    121.38905    168.77092
# 3  2025-05-31  156.97668    133.28575    180.66762
# 4  2025-06-01  151.56465    127.87372    175.25558
